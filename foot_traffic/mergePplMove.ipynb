# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

# %%
# 첫 번째 데이터셋을 불러옵니다.
data1 = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/seoul_air.csv')

# 두 번째 데이터셋을 불러옵니다.
data2 = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/merged_foot_traffic.csv')

# 두 데이터셋을 위아래로 연결합니다.
#merged_data = pd.concat([data1, data2], ignore_index=True)

# %%
data2.rename(columns={'자치구': 'Gu', '방문자수': 'VisitNum', '측정날짜': 'Date'}, inplace=True)
data2.head()
# Out:
#              Gu        Date  VisitNum
# 0     Dobong-gu  2023-01-01     832.0
# 1  Eunpyeong-gu  2023-01-01       8.0
# 2  Yangcheon-gu  2023-01-01     555.0
# 3    Gangbuk-gu  2023-01-01     457.0
# 4     Songpa-gu  2023-01-01     122.0

# %%
result = data1.merge(data2, left_index=True, right_index=True)

# %%
# 파일 경로 리스트
#file_paths = ['/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall1.csv',
#              '/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall2.csv',
#              '/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall3.csv',
#              '/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall4.csv',
#              '/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall5.csv',
#              '/content/drive/MyDrive/SWING/HOMERUN/edited_rainfall/edited_rainfall6.csv']  # 실제 파일 경로에 맞게 수정해야 합니다.

# 파일 병합
#RainFall = pd.concat([pd.read_csv(file) for file in file_paths], axis=0)

# %%
# 병합된 데이터 확인
result
# Out:
#       Unnamed: 0      Date_x Gu_x  PM10  PM2.5      O3     NO2    CO     SO2  \
# 0              0  2023-01-01  중랑구  52.0   39.0  0.0210  0.0300  0.70  0.0030
# 1              1  2023-01-01   중구  54.0   46.0  0.0260  0.0230  0.60  0.0040
# 2              2  2023-01-01  종로구  53.0   42.0  0.0250  0.0220  0.70  0.0040
# 3              3  2023-01-01  은평구  55.0   37.0  0.0230  0.0210  0.80  0.0040
# 4              4  2023-01-01  용산구  50.0   37.0  0.0240  0.0190  0.60  0.0040
# ...          ...         ...  ...   ...    ...     ...     ...   ...     ...
# 3504        3504  2023-05-15  관악구  39.0   21.0  0.0563  0.0233  0.47  0.0033
# 3505        3505  2023-05-15  강서구  41.0   21.0  0.0598  0.0207  0.49  0.0034
# 3506        3506  2023-05-15  강북구  36.0   20.0  0.0641  0.0133  0.40  0.0024
# 3507        3507  2023-05-15  강동구  34.0   21.0  0.0452  0.0184  0.35  0.0026
# 3508        3508  2023-05-15  강남구  35.0   20.0  0.0545  0.0233  0.38  0.0032
#
#                   Gu_y      Date_y  VisitNum
# ...

# %%
#RainFall.info()

# %%
# file2.rename(columns={'copy * foot_traffic_.csv모델번호': '모델번호'}, inplace=True)
# file2

# %%
# pplMove = pd.concat([file1, file2], axis=1, ignore_index=True)
# pplMove

# %%
# pplMove

# %%
#values = pplMove['측정시간'].str[:10]
#print(values)

# %%
# 컬럼이 모두 같은 값인지 확인

#unique_values = pplMove['측정시간'].str[:10].nunique()
#print(unique_values)

# %%
# 확인용

#pplMove.to_csv('output.csv', index=True)

# %%
#unique_values = combined_df['측정시간'].unique()
#print(len(unique_values))
#unique_values

# %%
#merged_data.head()

# %%
#RainFall.to_csv('/content/drive/MyDrive/SWING/HOMERUN/RainFall_final.csv', index=False)
