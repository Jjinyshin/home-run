# %% [markdown]
# ## 국가별 행복도를 봅시다

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/initData/World Happiness Report.csv')

# %%
df.head()
# Out:
#   Country Name Regional Indicator  Year  Life Ladder  Log GDP Per Capita  \
# 0  Afghanistan         South Asia  2008     3.723590            7.350416
# 1  Afghanistan         South Asia  2009     4.401778            7.508646
# 2  Afghanistan         South Asia  2010     4.758381            7.613900
# 3  Afghanistan         South Asia  2011     3.831719            7.581259
# 4  Afghanistan         South Asia  2012     3.782938            7.660506
#
#    Social Support  Healthy Life Expectancy At Birth  \
# 0        0.450662                         50.500000
# 1        0.552308                         50.799999
# 2        0.539075                         51.099998
# 3        0.521104                         51.400002
# 4        0.520637                         51.700001
#
#    Freedom To Make Life Choices  Generosity  Perceptions Of Corruption  \
# 0                      0.718114    0.167652                   0.881686
# ...

# %%
happiness = df.copy()

# %%
columns = ['Country Name', 'Year', 'Life Ladder']
happiness = df[columns]

# %%
happiness.head()
# Out:
#   Country Name  Year  Life Ladder
# 0  Afghanistan  2008     3.723590
# 1  Afghanistan  2009     4.401778
# 2  Afghanistan  2010     4.758381
# 3  Afghanistan  2011     3.831719
# 4  Afghanistan  2012     3.782938

# %%
happiness.to_csv('processed_happiness.csv', index=False)

# %%
# columns_to_drop = ['INDICATOR', 'MEASURE', 'FREQUENCY','Flag Codes']
# happiness.drop(columns=columns_to_drop, inplace=True)

# %%
unique_values = happiness['Country Name'].unique()
# len(unique_values)
unique_values
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Eswatini', 'Ethiopia', 'Finland',
#        'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong S.A.R. of China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
unique_values = happiness['Year'].unique()
# len(unique_values)
unique_values
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2019, 2021, 2022, 2007, 2020, 2006, 2005])

# %% [markdown]
# ## 행-공
# - 행복도와 공기질 데이터 같이보기

# %%
df = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/remeved_nan_merged_air_pollution.csv')
air_pollution = df.copy()

# %%
air_pollution.head()
# Out:
#   LOCATION  TIME        CO         CO2         GHG       NOX       SOX  \
# 0      AUS  1990  6064.261  276.693957  438082.427  1715.412  1678.077
# 1      AUS  1991  6079.665  278.077607  438074.634  1688.006  1660.795
# 2      AUS  1992  6233.789  282.213441  441777.454  1735.420  1746.540
# 3      AUS  1993  6467.664  286.269543  442307.562  1779.886  1841.100
# 4      AUS  1994  6614.625  292.441460  442635.414  1781.296  1863.377
#
#         VOC  PM2.5
# 0  1603.395   10.6
# 1  1593.365   10.1
# 2  1597.303    9.9
# 3  1614.664   10.2
# 4  1626.292   10.0

# %%
air_pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LOCATION  1078 non-null   object
#  1   TIME      1078 non-null   int64
#  2   CO        1078 non-null   float64
#  3   CO2       1078 non-null   float64
#  4   GHG       1078 non-null   float64
#  5   NOX       1078 non-null   float64
#  6   SOX       1078 non-null   float64
#  7   VOC       1078 non-null   float64
#  8   PM2.5     1078 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 75.9+ KB

# %%
air_pollution = air_pollution.sort_values(by='TIME')
air_pollution
# Out:
#      LOCATION  TIME         CO          CO2          GHG       NOX       SOX  \
# 0         AUS  1990   6064.261   276.693957   438082.427  1715.412  1678.077
# 356       FIN  1990    870.989    67.513610    71102.010   358.122   300.536
# 89        CAN  1990  12008.431   426.238109   588624.080  2382.445  3119.452
# 722       LVA  1990    659.950    25.827406    26032.475   133.262   138.164
# 1016      TUR  1990   2060.017   136.327861   219530.134   258.964  1717.157
# ...       ...   ...        ...          ...          ...       ...       ...
# 386       FIN  2020    370.433    49.150185    47764.918   115.866    27.363
# 1046      TUR  2020   1930.142   377.476204   523997.101   875.363  2195.178
# 355       EST  2020    242.152    18.747405    11415.663    41.589    19.594
# 293       DNK  2020    224.569    41.949737    44491.436   103.992    10.693
# 1077      USA  2020  40538.863  4275.188096  6025991.791  7265.792  1583.334
#
#             VOC  PM2.5
# ...

# %%
locations = air_pollution['LOCATION'].unique()
locations
# Out:
# array(['AUS', 'FIN', 'CAN', 'LVA', 'TUR', 'AUT', 'USA', 'FRA', 'LUX',
#        'BEL', 'GBR', 'JPN', 'GRC', 'ITA', 'HUN', 'ISL', 'NOR', 'EST',
#        'NLD', 'NZL', 'CHE', 'SWE', 'CRI', 'SVN', 'CZE', 'DEU', 'PRT',
#        'SVK', 'DNK', 'ESP', 'POL', 'IRL', 'LTU', 'ISR', 'KOR', 'MEX',
#        'CHL', 'RUS', 'COL'], dtype=object)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12, 6))
locations = air_pollution['LOCATION'].unique()

for location in locations:
  location_data = air_pollution[air_pollution['LOCATION'] == location]

  x = location_data['TIME']
  y = location_data['데이터_컬럼']
