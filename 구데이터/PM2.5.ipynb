# %%
import numpy as np
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/air_pollution.csv')

# %%
df.head()
# Out:
#   LOCATION     INDICATOR     SUBJECT    MEASURE FREQUENCY  TIME  Value  \
# 0      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  1990  7.602
# 1      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  1995  7.496
# 2      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2000  7.366
# 3      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2005  6.910
# 4      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2010  6.787
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#   LOCATION     INDICATOR     SUBJECT    MEASURE FREQUENCY  TIME  Value  \
# 0      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  1990  7.602
# 1      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  1995  7.496
# 2      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2000  7.366
# 3      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2005  6.910
# 4      AUS  POLLUTIONEXP  EXPOS2PM25  MICGRCUBM         A  2010  6.787
#
#    Flag Codes
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# - 아정이: drop
# - 진영: 컬럼분리

# %%
unique_values = df1['SUBJECT'].unique()
len(unique_values)
# Out:
# 1

# %%
df1['SUBJECT'] = df1['SUBJECT'].apply(lambda x: x[-4:])
df1.head()
# Out:
#   LOCATION     INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value  Flag Codes
# 0      AUS  POLLUTIONEXP    PM25  MICGRCUBM         A  1990  7.602         NaN
# 1      AUS  POLLUTIONEXP    PM25  MICGRCUBM         A  1995  7.496         NaN
# 2      AUS  POLLUTIONEXP    PM25  MICGRCUBM         A  2000  7.366         NaN
# 3      AUS  POLLUTIONEXP    PM25  MICGRCUBM         A  2005  6.910         NaN
# 4      AUS  POLLUTIONEXP    PM25  MICGRCUBM         A  2010  6.787         NaN

# %%
columns_to_drop = ['INDICATOR', 'MEASURE', 'FREQUENCY','Flag Codes']
df1.drop(columns=columns_to_drop, inplace=True)

# %%
df1.head()
# Out:
#   LOCATION SUBJECT  TIME  Value
# 0      AUS    PM25  1990  7.602
# 1      AUS    PM25  1995  7.496
# 2      AUS    PM25  2000  7.366
# 3      AUS    PM25  2005  6.910
# 4      AUS    PM25  2010  6.787

# %%
df1.rename(columns={'Value': 'PM25'}, inplace=True)
df1.head()
# Out:
#   LOCATION SUBJECT  TIME   PM25
# 0      AUS    PM25  1990  7.602
# 1      AUS    PM25  1995  7.496
# 2      AUS    PM25  2000  7.366
# 3      AUS    PM25  2005  6.910
# 4      AUS    PM25  2010  6.787

# %%
df1.drop('SUBJECT', axis=1, inplace=True)
df1.head()
# Out:
#   LOCATION  TIME   PM25
# 0      AUS  1990  7.602
# 1      AUS  1995  7.496
# 2      AUS  2000  7.366
# 3      AUS  2005  6.910
# 4      AUS  2010  6.787

# %%
df1.isna().sum()
# Out:
# LOCATION    0
# TIME        0
# PM25        0
# dtype: int64

# %%
df1.to_csv('pm25.csv', index=False)

# %%
df1.shape
# Out:
# (4872, 3)

# %%
unique_values = df1['LOCATION'].unique()
len(unique_values)
# Out:
# 174
