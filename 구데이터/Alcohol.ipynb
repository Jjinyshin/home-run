# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/SWING/HOMERUN/initData/Alcohol.csv')
df.head()
# Out:
#   LOCATION INDICATOR SUBJECT   MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS   ALCOHOL     TOT  LT_CAP15         A  1960    9.3        NaN
# 1      AUS   ALCOHOL     TOT  LT_CAP15         A  1961    9.4        NaN
# 2      AUS   ALCOHOL     TOT  LT_CAP15         A  1962    9.5        NaN
# 3      AUS   ALCOHOL     TOT  LT_CAP15         A  1963    9.8        NaN
# 4      AUS   ALCOHOL     TOT  LT_CAP15         A  1964   10.1        NaN

# %%
df1 = df.copy()

# %%
columns_to_drop = ['INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY','Flag Codes']
df1.drop(columns=columns_to_drop, inplace=True)
df1.head()
# Out:
#   LOCATION  TIME  Value
# 0      AUS  1960    9.3
# 1      AUS  1961    9.4
# 2      AUS  1962    9.5
# 3      AUS  1963    9.8
# 4      AUS  1964   10.1

# %%
unique_values = df1['LOCATION'].unique()
len(unique_values)
# Out:
# 49

# %%
df1.to_csv('Alcohol.csv', index=False)

# %%
missing_values = df1.isnull()
print(missing_values)
# Out:
#       LOCATION   TIME  Value
# 0        False  False  False
# 1        False  False  False
# 2        False  False  False
# 3        False  False  False
# 4        False  False  False
# ...        ...    ...    ...
# 2746     False  False  False
# 2747     False  False  False
# 2748     False  False  False
# 2749     False  False  False
# 2750     False  False  False
#
# [2751 rows x 3 columns]
